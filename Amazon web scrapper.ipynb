# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#connection

URL="https://www.amazon.in/Aaramkhor-Physics-T-Shirt-MAXWELLS-Equations/dp/B08DDKVKQ6/ref=asc_df_B08DDKVKQ6/?tag=googleshopdes-21&linkCode=df0&hvadid=506025285796&hvpos=&hvnetw=g&hvrand=8177228509568460912&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=1007772&hvtargid=pla-1211164439000&psc=1&ext_vrnc=hi"
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36","Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page=requests.get(URL,headers=headers)

soup1=BeautifulSoup(page.content,"html.parser")
#print(soup1)

soup2=BeautifulSoup(soup1.prettify(),"html.parser")


title=soup2.find(id="productTitle").get_text()
print(title)


spans = soup2.find('span', {'class' : 'a-price-whole'})
price=spans.get_text()
print(price)
# Out:
#                    Aaramkhor Physics T-Shirt for Men | Physics MAXWELLS Equations | Nerd | Regular Fit for Men Sizes S to 4XL|
#
#
#                    499
#
#                     .

# %%
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
price=price.strip()
print(price)

title=title.strip()
print(title)
import datetime 
date=datetime.date.today()
# Out:
# 499
#
#                     .
# Aaramkhor Physics T-Shirt for Men | Physics MAXWELLS Equations | Nerd | Regular Fit for Men Sizes S to 4XL|

# %%
#writing scrapped data in CSV file

import csv 
import pandas as pd

header = ['Title', 'Price','Date']
data = [title, price,date]

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

df=pd.read_csv(r'C:\Users\CharmiMeswani\Desktop\AmazonWebScraperDataset.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of                                                Title  \
# 0  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 1  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 2  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 3  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 4  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 5  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 6  Aaramkhor Physics T-Shirt for Men | Physics MA...
#
#                                              Price        Date
# 0  499\n                   \n                    .  2022-06-07
# 1  499\n                   \n                    .  2022-06-07
# 2  499\n                   \n                    .  2022-06-07
# 3  499\n                   \n                    .  2022-06-07
# 4  499\n                   \n                    .  2022-06-07
# 5  499\n                   \n                    .  2022-06-07
# 6  499\n                   \n                    .  2022-06-07  >

# %%
# automating web scrapping

import csv 
import pandas as pd
header = ['Title', 'Price','Date']
def check_price():
    URL="https://www.amazon.in/Aaramkhor-Physics-T-Shirt-MAXWELLS-Equations/dp/B08DDKVKQ6/ref=asc_df_B08DDKVKQ6/?tag=googleshopdes-21&linkCode=df0&hvadid=506025285796&hvpos=&hvnetw=g&hvrand=8177228509568460912&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=1007772&hvtargid=pla-1211164439000&psc=1&ext_vrnc=hi"
    headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36","Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page=requests.get(URL,headers=headers)

    soup1=BeautifulSoup(page.content,"html.parser")
    #print(soup1)

    soup2=BeautifulSoup(soup1.prettify(),"html.parser")


    title=soup2.find(id="productTitle").get_text()
    print(title)


    spans = soup2.find('span', {'class' : 'a-price-whole'})
    price=spans.get_text()
    print(price)
    price=price.strip()
    print(price)
    title=title.strip()
    print(title)
    import datetime 
    date=datetime.date.today()
    data = [title, price,date]
    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
        df=pd.read_csv(r'C:\Users\CharmiMeswani\Desktop\AmazonWebScraperDataset.csv')
        print(df.head)

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
#                    Aaramkhor Physics T-Shirt for Men | Physics MAXWELLS Equations | Nerd | Regular Fit for Men Sizes S to 4XL|
#
#
#                    499
#
#                     .
#
#
# 499
#
#                     .
# Aaramkhor Physics T-Shirt for Men | Physics MAXWELLS Equations | Nerd | Regular Fit for Men Sizes S to 4XL|
# <bound method NDFrame.head of                                                Title  \
# 0  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 1  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 2  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 3  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 4  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 5  Aaramkhor Physics T-Shirt for Men | Physics MA...
# 6  Aaramkhor Physics T-Shirt for Men | Physics MA...
#
#                                              Price        Date
# 0  499\n                   \n                    .  2022-06-07
# 1  499\n                   \n                    .  2022-06-07
# ...
